# %%
#Importing the required libraries
import pandas as pd
import numpy as np
import os
import cv2

# %%
labels = os.listdir("D:/Kaggle Projects/Driver Drowsiness Detector/train")

# %%
labels
# Out:
# ['Closed', 'no_yawn', 'Open', 'yawn']

# %% [markdown]
# # Visualize an Image

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(plt.imread("D:/Kaggle Projects/Driver Drowsiness Detector/train/Open/_0.jpg"))

# %%
plt.imshow(plt.imread("D:/Kaggle Projects/Driver Drowsiness Detector/train/Closed/_1.jpg"))

# %%
plt.imshow(plt.imread("D:/Kaggle Projects/Driver Drowsiness Detector/train/yawn/1.jpg"))

# %% [markdown]
# # Create an array of the image

# %%
imagearray = plt.imread("D:/Kaggle Projects/Driver Drowsiness Detector/train/yawn/10.jpg")

# %%
imagearray.shape
# Out:
# (480, 640, 3)

# %%
plt.imshow(plt.imread("D:/Kaggle Projects/Driver Drowsiness Detector/train/yawn/10.jpg"))
